# %% [markdown]
# global

# %%
x = 10

# %% [markdown]
# local

# %%
def func():
    y = 7
    x = 8
    print(x)
    print(y)

# %%
func()            
print(x)

# %% [markdown]
# enclosing

# %%
def outer():
    a = 7
    def inner():
        b = 9
        print(a)
        print(b)
    inner()
    print(a)

# %%
outer()

# %% [markdown]
# global keyword

# %%
count = 1
def counter():
    # global count
    count += 1
    print(count)

# %%
counter()
